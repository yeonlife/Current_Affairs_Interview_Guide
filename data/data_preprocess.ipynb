# %%
import pandas as pd

file_path = "data_crawling/crawling_data.csv"

df = pd.read_csv(file_path)
df.head(10)
# Out:
#    Unnamed: 0                                                 제목  \
# 0           0                   역대급 참패 후폭풍…국민의힘, 임명직당직자 일괄 사퇴 검토
# 1           1                군·여당, 하마스 공격 빗대며 ‘9·19 군사합의’ 무력화 시도
# 2           2   與 "통계조작은 국기문란" 野 "R&D 예산 삭감 굉장히 위험"…국감 3일차 여야 공방
# 3           3             국민의힘 지도부서 '김행 사퇴' 요구 나와... 윤 대통령 선택 주목
# 4           4                  與, 대통령실에 김행 여가부 장관 후보자 '사퇴 권고' 방침
# 5           5                       김행, 자진 사퇴…“尹정부·국힘 위한 선택 이것뿐”
# 6           6          과방위, 오염수로 또 충돌…야 "일본에 의존" 여 "가짜뉴스 선동"(종합)
# 7           7  “중국 내 억류됐던 탈북민 2600명 전원 강제북송돼… 하마스 테러 버금가는 반인도...
# 8           8                 尹대통령, 에스토니아 대통령과 정상회담…"방산 등 협력 확대"
# 9           9                      檢 ‘백현동 의혹’ 기소…이재명 기다리는 재판만 3건
#
#                                                   주소  \
# 0  https://n.news.naver.com/mnews/article/018/000...
# 1  https://n.news.naver.com/mnews/article/032/000...
# 2  https://n.news.naver.com/mnews/article/088/000...
# ...
